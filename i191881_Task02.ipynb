# %%
from sklearn.model_selection import train_test_split
from numpy import mean
from numpy import absolute
from numpy import sqrt
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn import linear_model, tree, ensemble
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn import preprocessing
from sklearn import metrics
import pandas as pd
import numpy as np

# %%
# read data from .csv file and convert it to pandas dataframe
df = pd.read_csv('/home/abdullah/Downloads/ECG200_TRAIN.csv', delimiter="  ")
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
df
# Out:
#     -1.0000000e+00   5.0205548e-01   5.4216265e-01   7.2238348e-01  \
# 0              1.0        0.147647        0.804668        0.367771
# 1             -1.0        0.316646        0.243199        0.370471
# 2             -1.0        1.168874        2.075901        1.760140
# 3              1.0        0.648658        0.752026        2.636231
# 4              1.0        0.404733        1.280859        2.515148
# ..             ...             ...             ...             ...
# 94             1.0        0.581277        0.876188        1.042767
# 95            -1.0        2.689017        2.708703        2.008381
# 96            -1.0        0.197677        0.455417        0.973110
# 97             1.0        0.179500        1.038409        1.946421
# 98             1.0        0.073124        0.776054        2.181336
#
#      1.4288852e+00   2.1365158e+00   2.2811490e+00   1.9362737e+00  \
# 0         0.243894        0.026614       -0.274402        0.096731
# ...

# %%
# le = preprocessing.LabelEncoder()
# df['Type'] = le.fit_transform(df['Type'])
# df['Temp'] = le.fit_transform(df['Temp'])
# df['BP'] = le.fit_transform(df['BP'])

# %%
    # for i in df['Age']:
    #     if i < 12:
    #         df['Age'] = df['Age'].replace(i, 1)
    #     elif i >= 12 and i < 20:
    #         df['Age'] = df['Age'].replace(i, 2)
    #     elif i >= 20 and i < 55:
    #         df['Age'] = df['Age'].replace(i, 3)
    #     elif i >= 55:
    #         df['Age'] = df['Age'].replace(i, 4)

# %%
# df

# %%
# modeI = df['Intensity'].mode()
# df["Intensity"]=df['Intensity'].fillna(modeI[0])
# df.info()

# %%
# intensity = df['Intensity']
# # intensity
# intensity.string.strip('mg')

# for i in len(intensity):
#     if intensity[i] == 'Low':
#         intensity[i] = 1
#     elif intensity[i] == 'Medium':
#         intensity[i] = 2
#     elif intensity[i] == 'High':
#         intensity[i] = 3

# %%
#apply kfold cross validation on the df dataframe
x = df.iloc[:, 1:98]
y = df. iloc[:, 0:1]

# %%
print("Features", x,sep="\n")
# Out:
# Features
#      5.0205548e-01   5.4216265e-01   7.2238348e-01   1.4288852e+00  \
# 0         0.147647        0.804668        0.367771        0.243894
# 1         0.316646        0.243199        0.370471        1.063738
# 2         1.168874        2.075901        1.760140        1.606446
# 3         0.648658        0.752026        2.636231        3.455716
# 4         0.404733        1.280859        2.515148        1.299519
# ..             ...             ...             ...             ...
# 94        0.581277        0.876188        1.042767        1.796120
# 95        2.689017        2.708703        2.008381        2.235800
# 96        0.197677        0.455417        0.973110        1.935956
# 97        0.179500        1.038409        1.946421        2.705141
# 98        0.073124        0.776054        2.181336        3.440325
#
#      2.1365158e+00   2.2811490e+00   1.9362737e+00   1.4688900e+00  \
# 0         0.026614       -0.274402        0.096731       -0.747731
# ...

# %%
print("Target Variable", y,sep="\n")
# Out:
# Target Variable
#     -1.0000000e+00
# 0              1.0
# 1             -1.0
# 2             -1.0
# 3              1.0
# 4              1.0
# ..             ...
# 94             1.0
# 95            -1.0
# 96            -1.0
# 97             1.0
# 98             1.0
#
# [99 rows x 1 columns]

# %%
kf =KFold(n_splits=5, shuffle=True, random_state=42)

cnt = 1

# %%
for train_index, test_index in kf.split(x, y):
    print(f'Fold:{cnt}, Train set: {len(train_index)}, Test set:{len(test_index)}')
    cnt += 1
    #modeI = df['Intensity'].mode()
# df["Intensity"]=df['Intensity'].fillna(modeI[0]
# Out:
# Fold:1, Train set: 79, Test set:20
# Fold:2, Train set: 79, Test set:20
# Fold:3, Train set: 79, Test set:20
# Fold:4, Train set: 79, Test set:20
# Fold:5, Train set: 80, Test set:19

# %%
x_train, x_test = x.iloc[train_index], x.iloc[test_index]
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
x_test
# Out:
#      5.0205548e-01   5.4216265e-01   7.2238348e-01   1.4288852e+00  \
# 1         0.316646        0.243199        0.370471        1.063738
# 2         1.168874        2.075901        1.760140        1.606446
# 14        2.248790        3.535038        2.888274        2.720920
# 20        0.087253        1.252048        1.970673        1.736905
# 21        0.470412        1.174849        2.221479        3.903861
# 23        0.475276        1.343113        2.784832        2.887771
# 29       -0.157389        0.736981        2.499638        3.052124
# 37        1.616336        2.099727        1.787912        1.328062
# 51        2.113051        3.239054        2.557642        2.315672
# 52       -0.194413       -1.100715       -1.321589       -0.814883
# 60        1.221512        3.521577        3.627613        3.076993
# 71        0.508719        0.809686        1.552808        1.981687
# 74        0.566884        0.592768        2.150568        3.301965
# ...

# %%
y_test
# Out:
#     -1.0000000e+00
# 1             -1.0
# 2             -1.0
# 14             1.0
# 20             1.0
# 21             1.0
# 23             1.0
# 29             1.0
# 37             1.0
# 51             1.0
# 52            -1.0
# 60            -1.0
# 71            -1.0
# 74             1.0
# 82            -1.0
# 83            -1.0
# 86             1.0
# 87            -1.0
# 90             1.0
# 92            -1.0

# %%
x_train, y_train = make_classification(n_samples=99, n_features=96)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 52.63157894736842
