# %% [markdown]
# # Question # 01

# %%
# Use naïve bayes classifer on the Tennis play dataset, your code should ask the user to input some features and return the class of the input
import pandas as pd
import numpy as np

df = pd.read_csv('/home/abdullah/Downloads/play_tennis.csv')
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
df=df.drop('day',axis=1)

# %%
df
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %%
# Use naive bayes classifier on the Tennis play dataset, your code should ask the user to input features such as outlook, temperature, humidity, wind and return the class of the input
def naive_bayes_classifier(att1,att2,att3,att4):
    countatt1no = 0
    countatt2no = 0
    countatt3no = 0
    countatt4no = 0
    a = len(df['outlook'])
    #print("total >> ", num)
    for i in range (0, len(df['outlook'])):
        if ((df['outlook'][i] == att1) and (df['play'][i] == 'No')):
            countatt1no+=1
    for i in range (0, len(df['temp'])):
        if ((df['temp'][i] == att2)   and (df['play'][i] == 'No')):
            countatt2no+=1
    for i in range (0, len(df['humidity'])):
        if ((df['humidity'][i] == att3) and (df['play'][i] == 'No')):
            countatt3no+=1
    for i in range (0, len(df['wind'])):
        if ((df['wind'][i] == att4) and (df['play'][i] == 'No')):
            countatt4no+=1
            
    countatt1yes = 0
    countatt2yes = 0
    countatt3yes = 0
    countatt4yes = 0
    
    for i in range (0, len(df['outlook'])):
        if ((df['outlook'][i] == att1) and (df['play'][i] == 'Yes')):
            countatt1yes+=1
    for i in range (0, len(df['temp'])):
        if ((df['temp'][i] == att2)   and (df['play'][i] == 'Yes')):
            countatt2yes+=1
            
    for i in range (0, len(df['humidity'])):
        if ((df['humidity'][i] == att3) and (df['play'][i] == 'Yes')):
            countatt3yes+=1
    for i in range (0, len(df['wind'])):
        if ((df['wind'][i] == att4) and (df['play'][i] == 'Yes')):
            countatt4yes+=1
            
    yes_count = 0
    no_count = 0
    for i in range (0, len(df['play'])):
        if (df['play'][i] == 'Yes'):
            yes_count+=1
    for i in range (0, len(df['play'])):
        if (df['play'][i] == 'No'):
            no_count+=1

    all_yes =0
    all_no =0
    
    for i in range(0, len(df['play'])):
        if df['play'][i] == 'Yes':
            all_yes+=1
        else:
            all_no+=1
            
    p_yes = all_yes/len(df['play'])
    p_no = all_no/len(df['play'])
    
    #find probability of playing tennis
    p_att1yes = countatt1yes/all_yes
    p_att2yes = countatt2yes/all_yes
    p_att3yes = countatt3yes/all_yes
    p_att4yes = countatt4yes/all_yes
    
    yes_prob = p_yes*p_att1yes*p_att2yes*p_att3yes*p_att4yes
    print("Probability of playing tennis is: ", yes_prob)
    
    #find probability of not playing tennis
    p_att1no = countatt1no/all_no
    p_att2no = countatt2no/all_no
    p_att3no = countatt3no/all_no
    p_att4no = countatt4no/all_no
    
    no_prob = p_no*p_att1no*p_att2no*p_att3no*p_att4no
    
    print("Probability of not playing tennis is: ", no_prob)
    
    if yes_prob > no_prob:
        print("Can play tennis")
        
    else:
        print("Can not play tennis")

# %%
naive_bayes_classifier("Sunny", "Cool", "Normal", "Weak")
# Out:
# Probability of playing tennis is:  0.021164021164021163
# Probability of not playing tennis is:  0.003428571428571429
# Can play tennis

# %% [markdown]
# # Question # 02

# %%
pos_sentence = "I love Mangoes mangoes are a lot tastier than other fruits I like mangoes because they are good Apples are good too but I prefer mangoes People say mango is the king of fruit so that is why mangoes are good mangoes are good because they are juicy"
neg_sentence = "Eating too many Mangoes can have a negative impact on your health mangoes are good but not too good, I like apples more than mangoes I don’t like mangoes because they are expensive Mangoes are not good I don’t like mangoes"

pos_sentence = pos_sentence.lower()
neg_sentence = neg_sentence.lower()

# %%
def naiveBayes(sent):
    
    array = sent.split()
    pos_sen = pos_sentence.split()
    p_sen = len(pos_sen)
   
    countA = 0
    countB = 0
    countC = 0
    
    for i in range (0, len(pos_sen)):
        if (pos_sen[i] == array[0]):
            countA+=1
        if (pos_sen[i] == array[1]):
            countB+=1 
        if (pos_sen[i] == array[2]):
            countC+=1
     
    prob_pos = ((countA/p_sen) * (countB/p_sen) * (countC/p_sen) * (5/11))
    
    
    neg_sen = neg_sentence.split()
    
    n_sen = len(neg_sen)
    
    wordA = 0
    wordB = 0
    wordC = 0
   
    for i in range (0, len(neg_sen)):
        if (neg_sen[i] == array[0]):
            wordA+=1
        if (neg_sen[i] == array[1]):
            wordB+=1
        if (neg_sen[i] == array[2]):
            wordC+=1
        
    prob_neg = ((wordA/n_sen) * (wordB/n_sen) * (wordC/n_sen) * (6/11))
    
    if prob_pos > prob_neg:
        print("Positive Sentece")
    else:
        print("Negative Sentence")

# %%
naiveBayes("mangoes are good")
naiveBayes("mangoes not good")
# Out:
# Positive Sentece
# Negative Sentence

# %%
def b_ayes1(sent):
    array = sent.split()
    pos_sen = pos_sentence.split()
    p_sen = len(pos_sen)
    countA = 0
    countB = 0
    countC = 0
    flag1 = 0
    flag2 = 0
    for i in range (0, p_sen):
        if (pos_sen[i] == array[0]):
            countA+=1
            flag1 = 1 
        if flag1 == 1: 
            if (pos_sen[i] == array[1]):
                countB+=1
                flag2 = 1 
        if flag2 == 1:    
            if (pos_sen[i] == array[2]):
                countC+=1
    

    positiveprob = (( (countA/p_sen) * (countB/p_sen) * (countC/p_sen) ) * (5/11) )  

    neg_sen = neg_sentence.split()

    n_sen = len(neg_sen)
    wordA = 0
    wordB = 0
    wordC = 0

    wflag1 = 0
    wflag2 = 0
    for i in range (0, n_sen):
        if (neg_sen[i] == array[0]):
            wordA+=1
            wflag1 = 1
        if wflag1 == 1:
            if (neg_sen[i] == array[1]):
                countB+=1
                wflag2 = 1
        if wflag2 == 1:    
            if (neg_sen[i] == array[2]):
                countC+=1

    negativeprob = (( (wordA/p_sen) * (wordB/p_sen) * (wordC/p_sen) ) * (6/11) )  
    
    if positiveprob > negativeprob:
        print("POSTIVE")
    else:
        print("NEGATIVE")

# %%
b_ayes1("mangoes are good")
b_ayes1("mangoes not good")
# Out:
# POSTIVE
# NEGATIVE
